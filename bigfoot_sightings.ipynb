# %% [markdown]
# <a href="https://colab.research.google.com/github/joshtype/bigFootbigData/blob/main/bigfoot_sightings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# BIGFOOT SIGHTINGS COLLECTED BY BFRO

# GOALS:
  # 0) Clean data
  # 1) Visualization:
        # Tabular:
            # basic stats
            # months/years/states not included (if any)
        # Qualitative:
            # histo classification vs sightings
            # histo location types vs classifications
        # Quantitative:
            # barchart sightings for each year
            # scatterplot sightings for each month
            # linechart sightings across all months/years
        # Geographic:
            # map sightings using lat/long data
  # 2) Prediction:
        # use probability to determine best month to sight bigfoot
            # co-relate that to state with highest number sightings
        # use TensorFlow to predict likelihood of sightings
            # using month and latitude/longitude

# Notes on dataset:
  # Host: www.kaggle.com/datasets/chemcnabb/bfro-bigfoot-sighting-report/.
  # Source: collected by Bigfoot Field Research Organization (BFRO).
  # Contains related datapoints to U.S. bigfoot sightings, 1970s - 2010s.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read raw csv file, store in a variable
raw = pd.read_csv("/content/drive/MyDrive/Data1501/Datasets/bigfoot-sightings.csv")
# load data to DataFrame
df = pd.DataFrame(raw)
# test top 10 rows
df.iloc[:10]

# %%
# CLEAN DATA:
# drop irrelevant 'number' col
df2 = df.drop('number', axis=1)

# slice relevant 'timestamp' values to new cols (truncating flawed vals)
df2['mm'] = df2['timestamp'].str.slice(5,7)    # slice months (x,y]
df2['dd'] = df2['timestamp'].str.slice(8,10)   # slice days   (x,y]
df2['yyyy'] = df2['timestamp'].str.slice(0,4)  # slice years  (x,y]

# drop unnecessary 'timestamp' col
df3 = df2.drop('timestamp', axis=1)

# drop unnecessary 'title' col
df4 = df3.drop('title', axis=1)

df4.iloc[:10]  # top 10 rows

# %%
# SUMMARIZE DATA:
# store each col in a variable
dd = df4.dd
mm = df4.mm
year = df4.yyyy
lat = df4.latitude
lon = df4.longitude
grade = df4.classification

# get number sightings (num rows)
num_sights = len(df.index)

# get basic stats
basic_stats = df4.describe()

# %%
# MANIPULATE DATA:
# convert values from str to int or float
for x in dd:
  x = int(x)
for x in mm:
  x = int(x)
for x in year:
  x = int(x)
for x in lat:
  x = float(x)
for x in lon:
  x = float(x)

# %%
# VISUALIZE DATA:
# histograph classification grades
plt.hist(grade)
plt.ylabel("Number of Sightings")
plt.xlabel("Classification of Each Sighting")
plt.yticks(range(0,1950,75))
plt.figure(figsize=(8,8))
plt.show()
